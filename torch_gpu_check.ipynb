# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.9661, 0.7149, 0.0057],
#         [0.1756, 0.3958, 0.7481],
#         [0.7937, 0.3870, 0.1802],
#         [0.8675, 0.0359, 0.3559],
#         [0.4645, 0.7522, 0.8716]])

# %%
# !pip install scikit-learn
# Out:
# ...
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      ---------------------------------------- 60.4/60.4 kB 3.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    - -------------------------------------- 0.4/10.6 MB 11.8 MB/s eta 0:00:01
#    --- ------------------------------------ 0.9/10.6 MB 10.9 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.3/10.6 MB 10.6 MB/s eta 0:00:01
#    ------ --------------------------------- 1.7/10.6 MB 9.9 MB/s eta 0:00:01
#    -------- ------------------------------- 2.1/10.6 MB 9.7 MB/s eta 0:00:01
#    --------- ------------------------------ 2.6/10.6 MB 9.9 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.1/10.6 MB 10.4 MB/s eta 0:00:01
#    ------------- -------------------------- 3.5/10.6 MB 10.1 MB/s eta 0:00:01
#    -------------- ------------------------- 4.0/10.6 MB 10.1 MB/s eta 0:00:01
# ...
